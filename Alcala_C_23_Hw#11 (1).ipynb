# %% [markdown]
# # PyObject:  Object-oriented programming HW 11

# %% [markdown]
# ## Exercise 1  (from Monday's class)

# %% [markdown]
# 1. Write a ``Particle`` class that can be used to represent a particle with a mass, a 3-d position, and a 3-d velocity.
#
# 2. Write a method that can be used to compute the kinetic energy of the particle
#
# 3. Write a method that takes another particle as an argument and finds the distance between the two particles
#
# 4. Write a method that given a time interval ``dt`` will update the position of the particle to the new position based on the current position and velocity.
#
# 5. Write a ``ChargedParticle`` class that inherits from the ``Particle`` class, but also has an attribute for the charge of the particle.

# %%
import numpy as np

class Particle(object):
    def __init__(self, x, y, z, vx, vy, vz, mass):
        self.x = x
        self.y = y
        self.z = z
        self.vx = vx
        self.vy = vy
        self.vz = vz
        self.m = mass
        
        def position(self,time):
            self.x += self.vx * time
            self.y += self.vx *time
            self.z += self.vz *time

particle = Particle(1, 2, 3, 4, 5, 6, 10)


        
print(particle.x, particle.y, particle.z)
# Out:
# 1 2 3

# %%
class Particle(object):
    def __init__(self, x, y, z, vx, vy, vz, mass):
        self.x = x
        self.y = y
        self.z = z
        self.vx = vx
        self.vy = vy
        self.vz = vz
        self.m = mass

    def kinetic_energy(self):
        speed = self.vx**2 + self.vy**2 + self.vz**2
        return (0.5) * self.m * speed  # 1/2 mv^2

particle = Particle(1, 2, 3, 4, 5, 6, 10)  

print(f"Kinetic Energy= {particle.kinetic_energy()}")
# Out:
# Kinetic Energy= 385.0

# %%
import math

class Particle:
    def __init__(self, x, y, z, vx, vy, vz, mass):
        self.x = x  
        self.y = y  
        self.z = z 
        self.vx = vx  
        self.vy = vy 
        self.vz = vz 
        self.m = mass  

    def kinetic_energy(self):
        speed = self.vx**2 + self.vy**2 + self.vz**2
        KE = 0.5 * self.m * speed
        return KE

    def distance_to(self, other_particle):

        dx = self.x - other_particle.x
        dy = self.y - other_particle.y
        dz = self.z - other_particle.z
        
        return math.sqrt(dx**2 + dy**2 + dz**2)
    
    def __repr__(self):
        return f"Particle(x={self.x}, y={self.y}, z={self.z}, vx={self.vx}, vy={self.vy}, vz={self.vz}, mass={self.m})"


particle1 = Particle(0, 0, 0, 1, 1, 1, 10)  
particle2 = Particle(3, 4, 5, -1, -2, 0, 15) 


distance = particle1.distance_to(particle2)
print(distance)
# Out:
# 7.0710678118654755

# %%
class Particle:
    def __init__(self, x, y, z, vx, vy, vz, mass):
        self.x = x  
        self.y = y 
        self.z = z  
        self.vx = vx 
        self.vy = vy  
        self.vz = vz  
        self.m = mass  

    def kinetic_energy(self):
        speed_squared = self.vx**2 + self.vy**2 + self.vz**2
        ke = 0.5 * self.m * speed_squared
        return ke

    def distance_to(self, other_particle):
        dx = self.x - other_particle.x
        dy = self.y - other_particle.y
        dz = self.z - other_particle.z
        return math.sqrt(dx**2 + dy**2 + dz**2)

    def new_position(self, dt):
        self.x += self.vx * dt
        self.y += self.vy * dt
        self.z += self.vz * dt
    
    def __repr__(self):
        return f"Particle(x={self.x}, y={self.y}, z={self.z}, vx={self.vx}, vy={self.vy}, vz={self.vz}, mass={self.m})"


particle1 = Particle(1, 2, 3, 4, 5, 6, 10)  


particle1.new_position(2)
print(f"New position of particle after 2 secs= {particle1}")
# Out:
# New position of particle after 2 secs= Particle(x=9, y=12, z=15, vx=4, vy=5, vz=6, mass=10)

# %% [markdown]
# ## Exercise 2  (New)

# %% [markdown]
# 6. Write a method that can be used to see if a particle is in the same place (e.g., find_seperation < 0.25).  If there are two ChargedParticles in the same place make a "simple" (*not correct physics*) "interaction". (__have the code print "interaction"__).
#
#     a. If the charges are opposite, make them "combine", set both velocities to zero and set their charge to zero, and print "merge".
#
#     b. Else, make the particles "repel", to do:
#
#         multiply each "self" velocity and  by (-1 * (self.charge+other.charge) * (self.mass/other.mass))
#
#         multiply each "other" velocity by (-1 * (self.charge+other.charge) * (other.mass/self.mass))
#
#     e.g., reversing it's velocity, and print "repel". __(Again this is bad physics, but we are focusing on coding so play along.)__
#
#
# 7. To test the above, write a code with two particles starting:
#
#         P1 at (x,y,z) = (-5,-5,-5) with (vx,vy,vz) = (1,1,1) and (charge = 0.5)
#
#         P2 at (x,y,z) = (5,5,5) with (vx,vy,vz) = (-1,-1,-1) and (charge = -0.5).
#
#     Use your dt time interval to move the particles in 0.05 time steps for 300 steps, and print the current poition and velocity of each particle at each time step.
#
#
# 8. To test the above, write a code with two particles starting:
#
#         P1 at (x,y,z) = (-5,-5,-5) with (vx,vy,vz) = (2,2,2) and (charge = 0.5)
#
#         P2 at (x,y,z) = (5,5,5) with (vx,vy,vz) = (-1,-1,-1) and (charge = 2.0).
#
#     Use your dt time interval to move the particles in 0.05 time steps for 300 steps, and print the current poition and velocity of each particle at each time step.

# %%
import math

class Particle:
    def __init__(self, x, y, z, vx, vy, vz, mass):
       
        self.x = x  
        self.y = y 
        self.z = z  
        self.vx = vx  
        self.vy = vy  
        self.vz = vz  
        self.m = mass  

    def kinetic_energy(self):
     
        speed_squared = self.vx**2 + self.vy**2 + self.vz**2
        ke = 0.5 * self.m * speed_squared
        return ke

    def distance_to(self, other_particle):
       
        dx = self.x - other_particle.x
        dy = self.y - other_particle.y
        dz = self.z - other_particle.z
        return math.sqrt(dx**2 + dy**2 + dz**2)

    def new_position(self, dt):
      
        self.x += self.vx * dt
        self.y += self.vy * dt
        self.z += self.vz * dt
    
    def __repr__(self):
      
        return f"Particle(x={self.x}, y={self.y}, z={self.z}, vx={self.vx}, vy={self.vy}, vz={self.vz}, mass={self.m})"


class ChargedParticle(Particle):
    def __init__(self, x, y, z, vx, vy, vz, mass, charge):
       
        super().__init__(x, y, z, vx, vy, vz, mass)  
        self.charge = charge  
    def __repr__(self):
       
        return f"ChargedParticle(x={self.x}, y={self.y}, z={self.z}, vx={self.vx}, vy={self.vy}, vz={self.vz}, mass={self.m}, charge={self.charge})"
    
    def find_interaction(self, other_particle):
     
        if self.distance_to(other_particle) < 0.25:
            print("interaction")


            if self.charge * other_particle.charge < 0:
                print("merge")
                self.vx = 0
                self.vy = 0
                self.vz = 0
                self.charge = 0

                other_particle.vx = 0
                other_particle.vy = 0
                other_particle.vz = 0
                other_particle.charge = 0
            else:
                print("repel")
               
                self.vx *= (-1 * (self.charge + other_particle.charge) * (self.m / other_particle.m))
                self.vy *= (-1 * (self.charge + other_particle.charge) * (self.m / other_particle.m))
                self.vz *= (-1 * (self.charge + other_particle.charge) * (self.m / other_particle.m))
                
                other_particle.vx *= (-1 * (self.charge + other_particle.charge) * (other_particle.m / self.m))
                other_particle.vy *= (-1 * (self.charge + other_particle.charge) * (other_particle.m / self.m))
                other_particle.vz *= (-1 * (self.charge + other_particle.charge) * (other_particle.m / self.m))


p1 = ChargedParticle(-5, -5, -5, 2, 2, 2, 10, 0.5)  
p2 = ChargedParticle(5, 5, 5, -1, -1, -1, 15, -0.5)  


dt = 0.025
steps = 300

for step in range(steps):
    p1.find_interaction(p2)

    p1.new_position(dt)
    p2.new_position(dt)


    print(f"Step {step+1}:")
    print(f" P1= ({p1.x}, {p1.y}, {p1.z}), Velocity: ({p1.vx}, {p1.vy}, {p1.vz})")
    print(f" P2 = ({p2.x}, {p2.y}, {p2.z}), Velocity: ({p2.vx}, {p2.vy}, {p2.vz})")
# Out:
# Step 1:
#  P1= (-4.95, -4.95, -4.95), Velocity: (2, 2, 2)
#  P2 = (4.975, 4.975, 4.975), Velocity: (-1, -1, -1)
# Step 2:
#  P1= (-4.9, -4.9, -4.9), Velocity: (2, 2, 2)
#  P2 = (4.949999999999999, 4.949999999999999, 4.949999999999999), Velocity: (-1, -1, -1)
# Step 3:
#  P1= (-4.8500000000000005, -4.8500000000000005, -4.8500000000000005), Velocity: (2, 2, 2)
#  P2 = (4.924999999999999, 4.924999999999999, 4.924999999999999), Velocity: (-1, -1, -1)
# Step 4:
#  P1= (-4.800000000000001, -4.800000000000001, -4.800000000000001), Velocity: (2, 2, 2)
#  P2 = (4.899999999999999, 4.899999999999999, 4.899999999999999), Velocity: (-1, -1, -1)
# Step 5:
#  P1= (-4.750000000000001, -4.750000000000001, -4.750000000000001), Velocity: (2, 2, 2)
#  P2 = (4.874999999999998, 4.874999999999998, 4.874999999999998), Velocity: (-1, -1, -1)
# Step 6:
#  P1= (-4.700000000000001, -4.700000000000001, -4.700000000000001), Velocity: (2, 2, 2)
#  P2 = (4.849999999999998, 4.849999999999998, 4.849999999999998), Velocity: (-1, -1, -1)
# Step 7:
#  P1= (-4.650000000000001, -4.650000000000001, -4.650000000000001), Velocity: (2, 2, 2)
#  P2 = (4.8249999999999975, 4.8249999999999975, 4.8249999999999975), Velocity: (-1, -1, -1)
# Step 8:
#  P1= (-4.600000000000001, -4.600000000000001, -4.600000000000001), Velocity: (2, 2, 2)
#  P2 = (4.799999999999997, 4.799999999999997, 4.799999999999997), Velocity: (-1, -1, -1)
# Step 9:
#  P1= (-4.550000000000002, -4.550000000000002, -4.550000000000002), Velocity: (2, 2, 2)
#  P2 = (4.774999999999997, 4.774999999999997, 4.774999999999997), Velocity: (-1, -1, -1)
# Step 10:
#  P1= (-4.500000000000002, -4.500000000000002, -4.500000000000002), Velocity: (2, 2, 2)
#  P2 = (4.7499999999999964, 4.7499999999999964, 4.7499999999999964), Velocity: (-1, -1, -1)
# Step 11:
#  P1= (-4.450000000000002, -4.450000000000002, -4.450000000000002), Velocity: (2, 2, 2)
#  P2 = (4.724999999999996, 4.724999999999996, 4.724999999999996), Velocity: (-1, -1, -1)
# Step 12:
#  P1= (-4.400000000000002, -4.400000000000002, -4.400000000000002), Velocity: (2, 2, 2)
#  P2 = (4.699999999999996, 4.699999999999996, 4.699999999999996), Velocity: (-1, -1, -1)
# Step 13:
#  P1= (-4.350000000000002, -4.350000000000002, -4.350000000000002), Velocity: (2, 2, 2)
#  P2 = (4.674999999999995, 4.674999999999995, 4.674999999999995), Velocity: (-1, -1, -1)
# Step 14:
#  P1= (-4.3000000000000025, -4.3000000000000025, -4.3000000000000025), Velocity: (2, 2, 2)
#  P2 = (4.649999999999995, 4.649999999999995, 4.649999999999995), Velocity: (-1, -1, -1)
# Step 15:
#  P1= (-4.250000000000003, -4.250000000000003, -4.250000000000003), Velocity: (2, 2, 2)
#  P2 = (4.624999999999995, 4.624999999999995, 4.624999999999995), Velocity: (-1, -1, -1)
# Step 16:
#  P1= (-4.200000000000003, -4.200000000000003, -4.200000000000003), Velocity: (2, 2, 2)
#  P2 = (4.599999999999994, 4.599999999999994, 4.599999999999994), Velocity: (-1, -1, -1)
# Step 17:
#  P1= (-4.150000000000003, -4.150000000000003, -4.150000000000003), Velocity: (2, 2, 2)
#  P2 = (4.574999999999994, 4.574999999999994, 4.574999999999994), Velocity: (-1, -1, -1)
# Step 18:
#  P1= (-4.100000000000003, -4.100000000000003, -4.100000000000003), Velocity: (2, 2, 2)
#  P2 = (4.549999999999994, 4.549999999999994, 4.549999999999994), Velocity: (-1, -1, -1)
# Step 19:
#  P1= (-4.050000000000003, -4.050000000000003, -4.050000000000003), Velocity: (2, 2, 2)
#  P2 = (4.524999999999993, 4.524999999999993, 4.524999999999993), Velocity: (-1, -1, -1)
# Step 20:
#  P1= (-4.0000000000000036, -4.0000000000000036, -4.0000000000000036), Velocity: (2, 2, 2)
#  P2 = (4.499999999999993, 4.499999999999993, 4.499999999999993), Velocity: (-1, -1, -1)
# Step 21:
#  P1= (-3.9500000000000037, -3.9500000000000037, -3.9500000000000037), Velocity: (2, 2, 2)
#  P2 = (4.4749999999999925, 4.4749999999999925, 4.4749999999999925), Velocity: (-1, -1, -1)
# Step 22:
#  P1= (-3.900000000000004, -3.900000000000004, -3.900000000000004), Velocity: (2, 2, 2)
#  P2 = (4.449999999999992, 4.449999999999992, 4.449999999999992), Velocity: (-1, -1, -1)
# Step 23:
#  P1= (-3.850000000000004, -3.850000000000004, -3.850000000000004), Velocity: (2, 2, 2)
#  P2 = (4.424999999999992, 4.424999999999992, 4.424999999999992), Velocity: (-1, -1, -1)
# Step 24:
#  P1= (-3.8000000000000043, -3.8000000000000043, -3.8000000000000043), Velocity: (2, 2, 2)
#  P2 = (4.3999999999999915, 4.3999999999999915, 4.3999999999999915), Velocity: (-1, -1, -1)
# Step 25:
#  P1= (-3.7500000000000044, -3.7500000000000044, -3.7500000000000044), Velocity: (2, 2, 2)
#  P2 = (4.374999999999991, 4.374999999999991, 4.374999999999991), Velocity: (-1, -1, -1)
# Step 26:
#  P1= (-3.7000000000000046, -3.7000000000000046, -3.7000000000000046), Velocity: (2, 2, 2)
#  P2 = (4.349999999999991, 4.349999999999991, 4.349999999999991), Velocity: (-1, -1, -1)
# Step 27:
#  P1= (-3.650000000000005, -3.650000000000005, -3.650000000000005), Velocity: (2, 2, 2)
#  P2 = (4.32499999999999, 4.32499999999999, 4.32499999999999), Velocity: (-1, -1, -1)
# Step 28:
#  P1= (-3.600000000000005, -3.600000000000005, -3.600000000000005), Velocity: (2, 2, 2)
#  P2 = (4.29999999999999, 4.29999999999999, 4.29999999999999), Velocity: (-1, -1, -1)
# Step 29:
#  P1= (-3.550000000000005, -3.550000000000005, -3.550000000000005), Velocity: (2, 2, 2)
#  P2 = (4.27499999999999, 4.27499999999999, 4.27499999999999), Velocity: (-1, -1, -1)
# Step 30:
#  P1= (-3.5000000000000053, -3.5000000000000053, -3.5000000000000053), Velocity: (2, 2, 2)
#  P2 = (4.249999999999989, 4.249999999999989, 4.249999999999989), Velocity: (-1, -1, -1)
# Step 31:
#  P1= (-3.4500000000000055, -3.4500000000000055, -3.4500000000000055), Velocity: (2, 2, 2)
#  P2 = (4.224999999999989, 4.224999999999989, 4.224999999999989), Velocity: (-1, -1, -1)
# Step 32:
#  P1= (-3.4000000000000057, -3.4000000000000057, -3.4000000000000057), Velocity: (2, 2, 2)
#  P2 = (4.199999999999989, 4.199999999999989, 4.199999999999989), Velocity: (-1, -1, -1)
# Step 33:
#  P1= (-3.350000000000006, -3.350000000000006, -3.350000000000006), Velocity: (2, 2, 2)
#  P2 = (4.174999999999988, 4.174999999999988, 4.174999999999988), Velocity: (-1, -1, -1)
# Step 34:
#  P1= (-3.300000000000006, -3.300000000000006, -3.300000000000006), Velocity: (2, 2, 2)
#  P2 = (4.149999999999988, 4.149999999999988, 4.149999999999988), Velocity: (-1, -1, -1)
# Step 35:
#  P1= (-3.250000000000006, -3.250000000000006, -3.250000000000006), Velocity: (2, 2, 2)
#  P2 = (4.124999999999988, 4.124999999999988, 4.124999999999988), Velocity: (-1, -1, -1)
# Step 36:
#  P1= (-3.2000000000000064, -3.2000000000000064, -3.2000000000000064), Velocity: (2, 2, 2)
#  P2 = (4.099999999999987, 4.099999999999987, 4.099999999999987), Velocity: (-1, -1, -1)
# Step 37:
#  P1= (-3.1500000000000066, -3.1500000000000066, -3.1500000000000066), Velocity: (2, 2, 2)
#  P2 = (4.074999999999987, 4.074999999999987, 4.074999999999987), Velocity: (-1, -1, -1)
# Step 38:
#  P1= (-3.1000000000000068, -3.1000000000000068, -3.1000000000000068), Velocity: (2, 2, 2)
#  P2 = (4.0499999999999865, 4.0499999999999865, 4.0499999999999865), Velocity: (-1, -1, -1)
# Step 39:
#  P1= (-3.050000000000007, -3.050000000000007, -3.050000000000007), Velocity: (2, 2, 2)
#  P2 = (4.024999999999986, 4.024999999999986, 4.024999999999986), Velocity: (-1, -1, -1)
# Step 40:
#  P1= (-3.000000000000007, -3.000000000000007, -3.000000000000007), Velocity: (2, 2, 2)
#  P2 = (3.9999999999999862, 3.9999999999999862, 3.9999999999999862), Velocity: (-1, -1, -1)
# Step 41:
#  P1= (-2.9500000000000073, -2.9500000000000073, -2.9500000000000073), Velocity: (2, 2, 2)
#  P2 = (3.9749999999999863, 3.9749999999999863, 3.9749999999999863), Velocity: (-1, -1, -1)
# Step 42:
#  P1= (-2.9000000000000075, -2.9000000000000075, -2.9000000000000075), Velocity: (2, 2, 2)
#  P2 = (3.9499999999999864, 3.9499999999999864, 3.9499999999999864), Velocity: (-1, -1, -1)
# Step 43:
#  P1= (-2.8500000000000076, -2.8500000000000076, -2.8500000000000076), Velocity: (2, 2, 2)
#  P2 = (3.9249999999999865, 3.9249999999999865, 3.9249999999999865), Velocity: (-1, -1, -1)
# Step 44:
#  P1= (-2.800000000000008, -2.800000000000008, -2.800000000000008), Velocity: (2, 2, 2)
#  P2 = (3.8999999999999866, 3.8999999999999866, 3.8999999999999866), Velocity: (-1, -1, -1)
# Step 45:
#  P1= (-2.750000000000008, -2.750000000000008, -2.750000000000008), Velocity: (2, 2, 2)
#  P2 = (3.8749999999999867, 3.8749999999999867, 3.8749999999999867), Velocity: (-1, -1, -1)
# Step 46:
#  P1= (-2.700000000000008, -2.700000000000008, -2.700000000000008), Velocity: (2, 2, 2)
#  P2 = (3.8499999999999868, 3.8499999999999868, 3.8499999999999868), Velocity: (-1, -1, -1)
# Step 47:
#  P1= (-2.6500000000000083, -2.6500000000000083, -2.6500000000000083), Velocity: (2, 2, 2)
#  P2 = (3.824999999999987, 3.824999999999987, 3.824999999999987), Velocity: (-1, -1, -1)
# Step 48:
#  P1= (-2.6000000000000085, -2.6000000000000085, -2.6000000000000085), Velocity: (2, 2, 2)
#  P2 = (3.799999999999987, 3.799999999999987, 3.799999999999987), Velocity: (-1, -1, -1)
# Step 49:
#  P1= (-2.5500000000000087, -2.5500000000000087, -2.5500000000000087), Velocity: (2, 2, 2)
#  P2 = (3.774999999999987, 3.774999999999987, 3.774999999999987), Velocity: (-1, -1, -1)
# Step 50:
#  P1= (-2.500000000000009, -2.500000000000009, -2.500000000000009), Velocity: (2, 2, 2)
#  P2 = (3.749999999999987, 3.749999999999987, 3.749999999999987), Velocity: (-1, -1, -1)
# Step 51:
#  P1= (-2.450000000000009, -2.450000000000009, -2.450000000000009), Velocity: (2, 2, 2)
#  P2 = (3.724999999999987, 3.724999999999987, 3.724999999999987), Velocity: (-1, -1, -1)
# Step 52:
#  P1= (-2.4000000000000092, -2.4000000000000092, -2.4000000000000092), Velocity: (2, 2, 2)
#  P2 = (3.6999999999999873, 3.6999999999999873, 3.6999999999999873), Velocity: (-1, -1, -1)
# Step 53:
#  P1= (-2.3500000000000094, -2.3500000000000094, -2.3500000000000094), Velocity: (2, 2, 2)
#  P2 = (3.6749999999999874, 3.6749999999999874, 3.6749999999999874), Velocity: (-1, -1, -1)
# Step 54:
#  P1= (-2.3000000000000096, -2.3000000000000096, -2.3000000000000096), Velocity: (2, 2, 2)
#  P2 = (3.6499999999999875, 3.6499999999999875, 3.6499999999999875), Velocity: (-1, -1, -1)
# Step 55:
#  P1= (-2.2500000000000098, -2.2500000000000098, -2.2500000000000098), Velocity: (2, 2, 2)
#  P2 = (3.6249999999999876, 3.6249999999999876, 3.6249999999999876), Velocity: (-1, -1, -1)
# Step 56:
#  P1= (-2.20000000000001, -2.20000000000001, -2.20000000000001), Velocity: (2, 2, 2)
#  P2 = (3.5999999999999877, 3.5999999999999877, 3.5999999999999877), Velocity: (-1, -1, -1)
# Step 57:
#  P1= (-2.15000000000001, -2.15000000000001, -2.15000000000001), Velocity: (2, 2, 2)
#  P2 = (3.5749999999999877, 3.5749999999999877, 3.5749999999999877), Velocity: (-1, -1, -1)
# Step 58:
#  P1= (-2.1000000000000103, -2.1000000000000103, -2.1000000000000103), Velocity: (2, 2, 2)
#  P2 = (3.549999999999988, 3.549999999999988, 3.549999999999988), Velocity: (-1, -1, -1)
# Step 59:
#  P1= (-2.0500000000000105, -2.0500000000000105, -2.0500000000000105), Velocity: (2, 2, 2)
#  P2 = (3.524999999999988, 3.524999999999988, 3.524999999999988), Velocity: (-1, -1, -1)
# Step 60:
#  P1= (-2.0000000000000107, -2.0000000000000107, -2.0000000000000107), Velocity: (2, 2, 2)
#  P2 = (3.499999999999988, 3.499999999999988, 3.499999999999988), Velocity: (-1, -1, -1)
# Step 61:
#  P1= (-1.9500000000000106, -1.9500000000000106, -1.9500000000000106), Velocity: (2, 2, 2)
#  P2 = (3.474999999999988, 3.474999999999988, 3.474999999999988), Velocity: (-1, -1, -1)
# Step 62:
#  P1= (-1.9000000000000106, -1.9000000000000106, -1.9000000000000106), Velocity: (2, 2, 2)
#  P2 = (3.449999999999988, 3.449999999999988, 3.449999999999988), Velocity: (-1, -1, -1)
# Step 63:
#  P1= (-1.8500000000000105, -1.8500000000000105, -1.8500000000000105), Velocity: (2, 2, 2)
#  P2 = (3.4249999999999883, 3.4249999999999883, 3.4249999999999883), Velocity: (-1, -1, -1)
# Step 64:
#  P1= (-1.8000000000000105, -1.8000000000000105, -1.8000000000000105), Velocity: (2, 2, 2)
#  P2 = (3.3999999999999884, 3.3999999999999884, 3.3999999999999884), Velocity: (-1, -1, -1)
# Step 65:
#  P1= (-1.7500000000000104, -1.7500000000000104, -1.7500000000000104), Velocity: (2, 2, 2)
#  P2 = (3.3749999999999885, 3.3749999999999885, 3.3749999999999885), Velocity: (-1, -1, -1)
# Step 66:
#  P1= (-1.7000000000000104, -1.7000000000000104, -1.7000000000000104), Velocity: (2, 2, 2)
#  P2 = (3.3499999999999885, 3.3499999999999885, 3.3499999999999885), Velocity: (-1, -1, -1)
# Step 67:
#  P1= (-1.6500000000000103, -1.6500000000000103, -1.6500000000000103), Velocity: (2, 2, 2)
#  P2 = (3.3249999999999886, 3.3249999999999886, 3.3249999999999886), Velocity: (-1, -1, -1)
# Step 68:
#  P1= (-1.6000000000000103, -1.6000000000000103, -1.6000000000000103), Velocity: (2, 2, 2)
#  P2 = (3.2999999999999887, 3.2999999999999887, 3.2999999999999887), Velocity: (-1, -1, -1)
# Step 69:
#  P1= (-1.5500000000000103, -1.5500000000000103, -1.5500000000000103), Velocity: (2, 2, 2)
#  P2 = (3.274999999999989, 3.274999999999989, 3.274999999999989), Velocity: (-1, -1, -1)
# Step 70:
#  P1= (-1.5000000000000102, -1.5000000000000102, -1.5000000000000102), Velocity: (2, 2, 2)
#  P2 = (3.249999999999989, 3.249999999999989, 3.249999999999989), Velocity: (-1, -1, -1)
# Step 71:
#  P1= (-1.4500000000000102, -1.4500000000000102, -1.4500000000000102), Velocity: (2, 2, 2)
#  P2 = (3.224999999999989, 3.224999999999989, 3.224999999999989), Velocity: (-1, -1, -1)
# Step 72:
#  P1= (-1.4000000000000101, -1.4000000000000101, -1.4000000000000101), Velocity: (2, 2, 2)
#  P2 = (3.199999999999989, 3.199999999999989, 3.199999999999989), Velocity: (-1, -1, -1)
# Step 73:
#  P1= (-1.35000000000001, -1.35000000000001, -1.35000000000001), Velocity: (2, 2, 2)
#  P2 = (3.174999999999989, 3.174999999999989, 3.174999999999989), Velocity: (-1, -1, -1)
# Step 74:
#  P1= (-1.30000000000001, -1.30000000000001, -1.30000000000001), Velocity: (2, 2, 2)
#  P2 = (3.1499999999999893, 3.1499999999999893, 3.1499999999999893), Velocity: (-1, -1, -1)
# Step 75:
#  P1= (-1.25000000000001, -1.25000000000001, -1.25000000000001), Velocity: (2, 2, 2)
#  P2 = (3.1249999999999893, 3.1249999999999893, 3.1249999999999893), Velocity: (-1, -1, -1)
# Step 76:
#  P1= (-1.20000000000001, -1.20000000000001, -1.20000000000001), Velocity: (2, 2, 2)
#  P2 = (3.0999999999999894, 3.0999999999999894, 3.0999999999999894), Velocity: (-1, -1, -1)
# Step 77:
#  P1= (-1.15000000000001, -1.15000000000001, -1.15000000000001), Velocity: (2, 2, 2)
#  P2 = (3.0749999999999895, 3.0749999999999895, 3.0749999999999895), Velocity: (-1, -1, -1)
# Step 78:
#  P1= (-1.1000000000000099, -1.1000000000000099, -1.1000000000000099), Velocity: (2, 2, 2)
#  P2 = (3.0499999999999896, 3.0499999999999896, 3.0499999999999896), Velocity: (-1, -1, -1)
# Step 79:
#  P1= (-1.0500000000000098, -1.0500000000000098, -1.0500000000000098), Velocity: (2, 2, 2)
#  P2 = (3.0249999999999897, 3.0249999999999897, 3.0249999999999897), Velocity: (-1, -1, -1)
# Step 80:
#  P1= (-1.0000000000000098, -1.0000000000000098, -1.0000000000000098), Velocity: (2, 2, 2)
#  P2 = (2.99999999999999, 2.99999999999999, 2.99999999999999), Velocity: (-1, -1, -1)
# Step 81:
#  P1= (-0.9500000000000097, -0.9500000000000097, -0.9500000000000097), Velocity: (2, 2, 2)
#  P2 = (2.97499999999999, 2.97499999999999, 2.97499999999999), Velocity: (-1, -1, -1)
# Step 82:
#  P1= (-0.9000000000000097, -0.9000000000000097, -0.9000000000000097), Velocity: (2, 2, 2)
#  P2 = (2.94999999999999, 2.94999999999999, 2.94999999999999), Velocity: (-1, -1, -1)
# Step 83:
#  P1= (-0.8500000000000096, -0.8500000000000096, -0.8500000000000096), Velocity: (2, 2, 2)
#  P2 = (2.92499999999999, 2.92499999999999, 2.92499999999999), Velocity: (-1, -1, -1)
# Step 84:
#  P1= (-0.8000000000000096, -0.8000000000000096, -0.8000000000000096), Velocity: (2, 2, 2)
#  P2 = (2.89999999999999, 2.89999999999999, 2.89999999999999), Velocity: (-1, -1, -1)
# Step 85:
#  P1= (-0.7500000000000095, -0.7500000000000095, -0.7500000000000095), Velocity: (2, 2, 2)
#  P2 = (2.8749999999999902, 2.8749999999999902, 2.8749999999999902), Velocity: (-1, -1, -1)
# Step 86:
#  P1= (-0.7000000000000095, -0.7000000000000095, -0.7000000000000095), Velocity: (2, 2, 2)
#  P2 = (2.8499999999999903, 2.8499999999999903, 2.8499999999999903), Velocity: (-1, -1, -1)
# Step 87:
#  P1= (-0.6500000000000095, -0.6500000000000095, -0.6500000000000095), Velocity: (2, 2, 2)
#  P2 = (2.8249999999999904, 2.8249999999999904, 2.8249999999999904), Velocity: (-1, -1, -1)
# Step 88:
#  P1= (-0.6000000000000094, -0.6000000000000094, -0.6000000000000094), Velocity: (2, 2, 2)
#  P2 = (2.7999999999999905, 2.7999999999999905, 2.7999999999999905), Velocity: (-1, -1, -1)
# Step 89:
#  P1= (-0.5500000000000094, -0.5500000000000094, -0.5500000000000094), Velocity: (2, 2, 2)
#  P2 = (2.7749999999999906, 2.7749999999999906, 2.7749999999999906), Velocity: (-1, -1, -1)
# Step 90:
#  P1= (-0.5000000000000093, -0.5000000000000093, -0.5000000000000093), Velocity: (2, 2, 2)
#  P2 = (2.7499999999999907, 2.7499999999999907, 2.7499999999999907), Velocity: (-1, -1, -1)
# Step 91:
#  P1= (-0.45000000000000934, -0.45000000000000934, -0.45000000000000934), Velocity: (2, 2, 2)
#  P2 = (2.7249999999999908, 2.7249999999999908, 2.7249999999999908), Velocity: (-1, -1, -1)
# Step 92:
#  P1= (-0.40000000000000935, -0.40000000000000935, -0.40000000000000935), Velocity: (2, 2, 2)
#  P2 = (2.699999999999991, 2.699999999999991, 2.699999999999991), Velocity: (-1, -1, -1)
# Step 93:
#  P1= (-0.35000000000000936, -0.35000000000000936, -0.35000000000000936), Velocity: (2, 2, 2)
#  P2 = (2.674999999999991, 2.674999999999991, 2.674999999999991), Velocity: (-1, -1, -1)
# Step 94:
#  P1= (-0.30000000000000937, -0.30000000000000937, -0.30000000000000937), Velocity: (2, 2, 2)
#  P2 = (2.649999999999991, 2.649999999999991, 2.649999999999991), Velocity: (-1, -1, -1)
# Step 95:
#  P1= (-0.2500000000000094, -0.2500000000000094, -0.2500000000000094), Velocity: (2, 2, 2)
#  P2 = (2.624999999999991, 2.624999999999991, 2.624999999999991), Velocity: (-1, -1, -1)
# Step 96:
#  P1= (-0.2000000000000094, -0.2000000000000094, -0.2000000000000094), Velocity: (2, 2, 2)
#  P2 = (2.599999999999991, 2.599999999999991, 2.599999999999991), Velocity: (-1, -1, -1)
# Step 97:
#  P1= (-0.1500000000000094, -0.1500000000000094, -0.1500000000000094), Velocity: (2, 2, 2)
#  P2 = (2.5749999999999913, 2.5749999999999913, 2.5749999999999913), Velocity: (-1, -1, -1)
# Step 98:
#  P1= (-0.1000000000000094, -0.1000000000000094, -0.1000000000000094), Velocity: (2, 2, 2)
#  P2 = (2.5499999999999914, 2.5499999999999914, 2.5499999999999914), Velocity: (-1, -1, -1)
# Step 99:
#  P1= (-0.0500000000000094, -0.0500000000000094, -0.0500000000000094), Velocity: (2, 2, 2)
#  P2 = (2.5249999999999915, 2.5249999999999915, 2.5249999999999915), Velocity: (-1, -1, -1)
# Step 100:
#  P1= (-9.395262345890387e-15, -9.395262345890387e-15, -9.395262345890387e-15), Velocity: (2, 2, 2)
#  P2 = (2.4999999999999916, 2.4999999999999916, 2.4999999999999916), Velocity: (-1, -1, -1)
# Step 101:
#  P1= (0.04999999999999061, 0.04999999999999061, 0.04999999999999061), Velocity: (2, 2, 2)
#  P2 = (2.4749999999999917, 2.4749999999999917, 2.4749999999999917), Velocity: (-1, -1, -1)
# Step 102:
#  P1= (0.09999999999999061, 0.09999999999999061, 0.09999999999999061), Velocity: (2, 2, 2)
#  P2 = (2.4499999999999917, 2.4499999999999917, 2.4499999999999917), Velocity: (-1, -1, -1)
# Step 103:
#  P1= (0.1499999999999906, 0.1499999999999906, 0.1499999999999906), Velocity: (2, 2, 2)
#  P2 = (2.424999999999992, 2.424999999999992, 2.424999999999992), Velocity: (-1, -1, -1)
# Step 104:
#  P1= (0.19999999999999063, 0.19999999999999063, 0.19999999999999063), Velocity: (2, 2, 2)
#  P2 = (2.399999999999992, 2.399999999999992, 2.399999999999992), Velocity: (-1, -1, -1)
# Step 105:
#  P1= (0.24999999999999062, 0.24999999999999062, 0.24999999999999062), Velocity: (2, 2, 2)
#  P2 = (2.374999999999992, 2.374999999999992, 2.374999999999992), Velocity: (-1, -1, -1)
# Step 106:
#  P1= (0.2999999999999906, 0.2999999999999906, 0.2999999999999906), Velocity: (2, 2, 2)
#  P2 = (2.349999999999992, 2.349999999999992, 2.349999999999992), Velocity: (-1, -1, -1)
# Step 107:
#  P1= (0.3499999999999906, 0.3499999999999906, 0.3499999999999906), Velocity: (2, 2, 2)
#  P2 = (2.324999999999992, 2.324999999999992, 2.324999999999992), Velocity: (-1, -1, -1)
# Step 108:
#  P1= (0.3999999999999906, 0.3999999999999906, 0.3999999999999906), Velocity: (2, 2, 2)
#  P2 = (2.2999999999999923, 2.2999999999999923, 2.2999999999999923), Velocity: (-1, -1, -1)
# Step 109:
#  P1= (0.4499999999999906, 0.4499999999999906, 0.4499999999999906), Velocity: (2, 2, 2)
#  P2 = (2.2749999999999924, 2.2749999999999924, 2.2749999999999924), Velocity: (-1, -1, -1)
# Step 110:
#  P1= (0.49999999999999056, 0.49999999999999056, 0.49999999999999056), Velocity: (2, 2, 2)
#  P2 = (2.2499999999999925, 2.2499999999999925, 2.2499999999999925), Velocity: (-1, -1, -1)
# Step 111:
#  P1= (0.5499999999999906, 0.5499999999999906, 0.5499999999999906), Velocity: (2, 2, 2)
#  P2 = (2.2249999999999925, 2.2249999999999925, 2.2249999999999925), Velocity: (-1, -1, -1)
# Step 112:
#  P1= (0.5999999999999907, 0.5999999999999907, 0.5999999999999907), Velocity: (2, 2, 2)
#  P2 = (2.1999999999999926, 2.1999999999999926, 2.1999999999999926), Velocity: (-1, -1, -1)
# Step 113:
#  P1= (0.6499999999999907, 0.6499999999999907, 0.6499999999999907), Velocity: (2, 2, 2)
#  P2 = (2.1749999999999927, 2.1749999999999927, 2.1749999999999927), Velocity: (-1, -1, -1)
# Step 114:
#  P1= (0.6999999999999907, 0.6999999999999907, 0.6999999999999907), Velocity: (2, 2, 2)
#  P2 = (2.149999999999993, 2.149999999999993, 2.149999999999993), Velocity: (-1, -1, -1)
# Step 115:
#  P1= (0.7499999999999908, 0.7499999999999908, 0.7499999999999908), Velocity: (2, 2, 2)
#  P2 = (2.124999999999993, 2.124999999999993, 2.124999999999993), Velocity: (-1, -1, -1)
# Step 116:
#  P1= (0.7999999999999908, 0.7999999999999908, 0.7999999999999908), Velocity: (2, 2, 2)
#  P2 = (2.099999999999993, 2.099999999999993, 2.099999999999993), Velocity: (-1, -1, -1)
# Step 117:
#  P1= (0.8499999999999909, 0.8499999999999909, 0.8499999999999909), Velocity: (2, 2, 2)
#  P2 = (2.074999999999993, 2.074999999999993, 2.074999999999993), Velocity: (-1, -1, -1)
# Step 118:
#  P1= (0.8999999999999909, 0.8999999999999909, 0.8999999999999909), Velocity: (2, 2, 2)
#  P2 = (2.049999999999993, 2.049999999999993, 2.049999999999993), Velocity: (-1, -1, -1)
# Step 119:
#  P1= (0.949999999999991, 0.949999999999991, 0.949999999999991), Velocity: (2, 2, 2)
#  P2 = (2.0249999999999932, 2.0249999999999932, 2.0249999999999932), Velocity: (-1, -1, -1)
# Step 120:
#  P1= (0.999999999999991, 0.999999999999991, 0.999999999999991), Velocity: (2, 2, 2)
#  P2 = (1.9999999999999933, 1.9999999999999933, 1.9999999999999933), Velocity: (-1, -1, -1)
# Step 121:
#  P1= (1.049999999999991, 1.049999999999991, 1.049999999999991), Velocity: (2, 2, 2)
#  P2 = (1.9749999999999934, 1.9749999999999934, 1.9749999999999934), Velocity: (-1, -1, -1)
# Step 122:
#  P1= (1.099999999999991, 1.099999999999991, 1.099999999999991), Velocity: (2, 2, 2)
#  P2 = (1.9499999999999935, 1.9499999999999935, 1.9499999999999935), Velocity: (-1, -1, -1)
# Step 123:
#  P1= (1.149999999999991, 1.149999999999991, 1.149999999999991), Velocity: (2, 2, 2)
#  P2 = (1.9249999999999936, 1.9249999999999936, 1.9249999999999936), Velocity: (-1, -1, -1)
# Step 124:
#  P1= (1.199999999999991, 1.199999999999991, 1.199999999999991), Velocity: (2, 2, 2)
#  P2 = (1.8999999999999937, 1.8999999999999937, 1.8999999999999937), Velocity: (-1, -1, -1)
# Step 125:
#  P1= (1.2499999999999911, 1.2499999999999911, 1.2499999999999911), Velocity: (2, 2, 2)
#  P2 = (1.8749999999999938, 1.8749999999999938, 1.8749999999999938), Velocity: (-1, -1, -1)
# Step 126:
#  P1= (1.2999999999999912, 1.2999999999999912, 1.2999999999999912), Velocity: (2, 2, 2)
#  P2 = (1.8499999999999939, 1.8499999999999939, 1.8499999999999939), Velocity: (-1, -1, -1)
# Step 127:
#  P1= (1.3499999999999912, 1.3499999999999912, 1.3499999999999912), Velocity: (2, 2, 2)
#  P2 = (1.824999999999994, 1.824999999999994, 1.824999999999994), Velocity: (-1, -1, -1)
# Step 128:
#  P1= (1.3999999999999913, 1.3999999999999913, 1.3999999999999913), Velocity: (2, 2, 2)
#  P2 = (1.799999999999994, 1.799999999999994, 1.799999999999994), Velocity: (-1, -1, -1)
# Step 129:
#  P1= (1.4499999999999913, 1.4499999999999913, 1.4499999999999913), Velocity: (2, 2, 2)
#  P2 = (1.7749999999999941, 1.7749999999999941, 1.7749999999999941), Velocity: (-1, -1, -1)
# Step 130:
#  P1= (1.4999999999999913, 1.4999999999999913, 1.4999999999999913), Velocity: (2, 2, 2)
#  P2 = (1.7499999999999942, 1.7499999999999942, 1.7499999999999942), Velocity: (-1, -1, -1)
# Step 131:
#  P1= (1.5499999999999914, 1.5499999999999914, 1.5499999999999914), Velocity: (2, 2, 2)
#  P2 = (1.7249999999999943, 1.7249999999999943, 1.7249999999999943), Velocity: (-1, -1, -1)
# Step 132:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (2, 2, 2)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (-1, -1, -1)
# interaction
# merge
# Step 133:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0, 0, 0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0, 0, 0)
# interaction
# repel
# Step 134:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 135:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 136:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 137:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 138:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 139:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 140:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 141:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 142:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 143:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 144:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 145:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 146:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 147:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 148:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 149:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 150:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 151:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 152:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 153:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 154:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 155:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 156:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 157:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 158:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 159:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 160:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 161:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 162:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 163:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 164:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 165:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 166:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 167:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 168:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 169:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 170:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 171:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 172:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 173:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 174:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 175:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 176:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 177:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 178:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 179:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 180:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 181:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 182:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 183:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 184:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 185:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 186:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 187:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 188:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 189:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 190:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 191:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 192:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 193:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 194:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 195:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 196:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 197:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 198:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 199:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 200:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 201:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 202:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 203:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 204:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 205:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 206:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 207:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 208:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 209:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 210:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 211:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 212:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 213:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 214:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 215:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 216:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 217:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 218:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 219:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 220:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 221:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 222:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 223:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 224:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 225:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 226:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 227:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 228:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 229:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 230:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 231:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 232:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 233:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 234:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 235:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 236:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 237:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 238:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 239:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 240:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 241:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 242:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 243:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 244:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 245:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 246:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 247:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 248:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 249:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 250:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 251:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 252:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 253:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 254:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 255:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 256:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 257:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 258:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 259:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 260:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 261:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 262:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 263:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 264:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 265:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 266:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 267:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 268:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 269:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 270:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 271:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 272:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 273:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 274:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 275:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 276:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 277:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 278:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 279:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 280:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 281:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 282:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 283:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 284:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 285:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 286:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 287:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 288:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 289:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 290:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 291:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 292:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 293:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 294:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 295:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 296:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 297:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 298:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 299:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
# interaction
# repel
# Step 300:
#  P1= (1.5999999999999914, 1.5999999999999914, 1.5999999999999914), Velocity: (0.0, 0.0, 0.0)
#  P2 = (1.6999999999999944, 1.6999999999999944, 1.6999999999999944), Velocity: (0.0, 0.0, 0.0)
